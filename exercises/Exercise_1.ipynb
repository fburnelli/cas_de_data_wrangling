# %% [markdown]
# # CAS Data Engineering FHNW
# ## Data Wrangling Module - Author F.Burnelli

# %% [markdown]
# ### Exercise 1

# %% [markdown]
# ### Note:use the Kernek: "Python (wrangling)"

# %% [markdown]
# ## Extract Data

# %%
import pandas as pd
import os
import sys   
import json

# %%
## Extract Data
file_name = 'lc_loan_dirty.csv'
data_folder = '../data'
file_path = os.path.join(os.getcwd(), data_folder, file_name)

df = pd.read_csv(file_path, low_memory=False)

# %% [markdown]
# # Exercise 1 Memory for csv - json - parquet
# Compare file size for fo csv,json and parquet

# %%
mem = sys.getsizeof(df.to_csv(index=False)) / (1024 * 1024)
print(f"Mem usage in MB CSV:{mem:.1f}")
mem = sys.getsizeof(df.to_json(orient='split')) / (1024 * 1024)
print(f"Mem usage in MB JSON - split:{mem:.1f}")
mem = sys.getsizeof(df.to_json(orient='records')) / (1024 * 1024)
print(f"Mem usage in MB JSON - records:{mem:.1f}")
mem = sys.getsizeof(df.to_json(orient='values')) / (1024 * 1024)
print(f"Mem usage in MB JSON - values:{mem:.1f}")
mem = sys.getsizeof(df.to_json(orient='index')) / (1024 * 1024)
print(f"Mem usage in MB JSON - index:{mem:.1f}")
mem = sys.getsizeof(df.to_json(orient='columns')) / (1024 * 1024)
print(f"Mem usage in MB JSON - columns:{mem:.1f}")
mem = sys.getsizeof(df.to_parquet())/ (1024 * 1024)
print(f"Mem usage in MB PARQUET:{mem:.1f}")
# Out:
# Mem usage in MB CSV:16.8
# Mem usage in MB JSON - split:10.7
# Mem usage in MB JSON - records:29.2
# Mem usage in MB JSON - values:10.6
# Mem usage in MB JSON - index:29.3
# Mem usage in MB JSON - columns:19.8
# Mem usage in MB PARQUET:2.4

# %% [markdown]
# ### json deep dive

# %%
pretty_json = json.dumps(json.loads(df.head(1).to_json(orient='records')), indent=4)
print(pretty_json)
# Out:
# [
#     {
#         "id": 1069453,
#         "member_id": 1303701,
#         "loan_amnt": 11000.0,
#         "funded_amnt": 11000.0,
#         "funded_amnt_inv": 11000.0,
#         "term": " 36 months",
#         "int_rate": 6.62,
#         "installment": 337.75,
#         "grade": "A",
#         "sub_grade": "A2",
#         "emp_title": "cognizant technology solutions",
#         "emp_length": "5 years",
#         "home_ownership": "RENT",
#         "annual_inc": 70000.0,
#         "verification_status": "Not Verified",
#         "issue_d": "Dec-2011",
#         "loan_status": "Fully Paid",
#         "pymnt_plan": "n",
#         "url": "https://www.lendingclub.com/browse/loanDetail.action?loan_id=1069453",
#         "desc": null,
#         "purpose": "debt_consolidation",
#         "title": "Debt Consolitation ",
#         "zip_code": "061xx",
#         "addr_state": "CT",
#         "dti": 10.85,
#         "delinq_2yrs": 0.0,
#         "earliest_cr_line": "Jan-2002",
#         "inq_last_6mths": 0.0,
#         "mths_since_last_delinq": null,
#         "mths_since_last_record": null,
#         "open_acc": 5.0,
#         "pub_rec": 0.0,
#         "revol_bal": 11638.0,
#         "revol_util": 36.4,
#         "total_acc": 7.0,
#         "initial_list_status": "f",
#         "out_prncp": 0.0,
#         "out_prncp_inv": 0.0,
#         "total_pymnt": 12157.3800468,
#         "total_pymnt_inv": 12157.38,
#         "total_rec_prncp": 11000.0,
#         "total_rec_int": 1157.38,
#         "total_rec_late_fee": 0.0,
#         "recoveries": 0.0,
#         "collection_recovery_fee": 0.0,
#         "last_pymnt_d": "Jan-2015",
#         "last_pymnt_amnt": 346.13,
#         "next_pymnt_d": null,
#         "last_credit_pull_d": "Jan-2016",
#         "collections_12_mths_ex_med": 0.0,
#         "mths_since_last_major_derog": null,
#         "policy_code": 1.0,
#         "application_type": "INDIVIDUAL",
#         "annual_inc_joint": null,
#         "dti_joint": null,
#         "verification_status_joint": null,
#         "acc_now_delinq": 0.0,
#         "tot_coll_amt": null,
#         "tot_cur_bal": null,
#         "open_acc_6m": null,
#         "open_il_6m": null,
#         "open_il_12m": null,
#         "open_il_24m": null,
#         "mths_since_rcnt_il": null,
#         "total_bal_il": null,
#         "il_util": null,
#         "open_rv_12m": null,
#         "open_rv_24m": null,
#         "max_bal_bc": null,
#         "all_util": null,
#         "total_rev_hi_lim": null,
#         "inq_fi": null,
#         "total_cu_tl": null,
#         "inq_last_12m": null
#     }
# ]

# %%
pretty_json = json.dumps(json.loads(df.head(1).to_json(orient='index')), indent=4)
print(pretty_json)
# Out:
# {
#     "0": {
#         "id": 1069453,
#         "member_id": 1303701,
#         "loan_amnt": 11000.0,
#         "funded_amnt": 11000.0,
#         "funded_amnt_inv": 11000.0,
#         "term": " 36 months",
#         "int_rate": 6.62,
#         "installment": 337.75,
#         "grade": "A",
#         "sub_grade": "A2",
#         "emp_title": "cognizant technology solutions",
#         "emp_length": "5 years",
#         "home_ownership": "RENT",
#         "annual_inc": 70000.0,
#         "verification_status": "Not Verified",
#         "issue_d": "Dec-2011",
#         "loan_status": "Fully Paid",
#         "pymnt_plan": "n",
#         "url": "https://www.lendingclub.com/browse/loanDetail.action?loan_id=1069453",
#         "desc": null,
#         "purpose": "debt_consolidation",
#         "title": "Debt Consolitation ",
#         "zip_code": "061xx",
#         "addr_state": "CT",
#         "dti": 10.85,
#         "delinq_2yrs": 0.0,
#         "earliest_cr_line": "Jan-2002",
#         "inq_last_6mths": 0.0,
#         "mths_since_last_delinq": null,
#         "mths_since_last_record": null,
#         "open_acc": 5.0,
#         "pub_rec": 0.0,
#         "revol_bal": 11638.0,
#         "revol_util": 36.4,
#         "total_acc": 7.0,
#         "initial_list_status": "f",
#         "out_prncp": 0.0,
#         "out_prncp_inv": 0.0,
#         "total_pymnt": 12157.3800468,
#         "total_pymnt_inv": 12157.38,
#         "total_rec_prncp": 11000.0,
#         "total_rec_int": 1157.38,
#         "total_rec_late_fee": 0.0,
#         "recoveries": 0.0,
#         "collection_recovery_fee": 0.0,
#         "last_pymnt_d": "Jan-2015",
#         "last_pymnt_amnt": 346.13,
#         "next_pymnt_d": null,
#         "last_credit_pull_d": "Jan-2016",
#         "collections_12_mths_ex_med": 0.0,
#         "mths_since_last_major_derog": null,
#         "policy_code": 1.0,
#         "application_type": "INDIVIDUAL",
#         "annual_inc_joint": null,
#         "dti_joint": null,
#         "verification_status_joint": null,
#         "acc_now_delinq": 0.0,
#         "tot_coll_amt": null,
#         "tot_cur_bal": null,
#         "open_acc_6m": null,
#         "open_il_6m": null,
#         "open_il_12m": null,
#         "open_il_24m": null,
#         "mths_since_rcnt_il": null,
#         "total_bal_il": null,
#         "il_util": null,
#         "open_rv_12m": null,
#         "open_rv_24m": null,
#         "max_bal_bc": null,
#         "all_util": null,
#         "total_rev_hi_lim": null,
#         "inq_fi": null,
#         "total_cu_tl": null,
#         "inq_last_12m": null
#     }
# }

# %%
pretty_json = json.dumps(json.loads(df.head(1).to_json(orient='columns')), indent=4)
print(pretty_json)
# Out:
# {
#     "id": {
#         "0": 1069453
#     },
#     "member_id": {
#         "0": 1303701
#     },
#     "loan_amnt": {
#         "0": 11000.0
#     },
#     "funded_amnt": {
#         "0": 11000.0
#     },
#     "funded_amnt_inv": {
#         "0": 11000.0
#     },
#     "term": {
#         "0": " 36 months"
#     },
#     "int_rate": {
#         "0": 6.62
#     },
#     "installment": {
#         "0": 337.75
#     },
#     "grade": {
#         "0": "A"
#     },
#     "sub_grade": {
#         "0": "A2"
#     },
#     "emp_title": {
#         "0": "cognizant technology solutions"
#     },
#     "emp_length": {
#         "0": "5 years"
#     },
#     "home_ownership": {
#         "0": "RENT"
#     },
#     "annual_inc": {
#         "0": 70000.0
#     },
#     "verification_status": {
#         "0": "Not Verified"
#     },
#     "issue_d": {
#         "0": "Dec-2011"
#     },
#     "loan_status": {
#         "0": "Fully Paid"
#     },
#     "pymnt_plan": {
#         "0": "n"
#     },
#     "url": {
#         "0": "https://www.lendingclub.com/browse/loanDetail.action?loan_id=1069453"
#     },
#     "desc": {
#         "0": null
#     },
#     "purpose": {
#         "0": "debt_consolidation"
#     },
#     "title": {
#         "0": "Debt Consolitation "
#     },
#     "zip_code": {
#         "0": "061xx"
#     },
#     "addr_state": {
#         "0": "CT"
#     },
#     "dti": {
#         "0": 10.85
#     },
#     "delinq_2yrs": {
#         "0": 0.0
#     },
#     "earliest_cr_line": {
#         "0": "Jan-2002"
#     },
#     "inq_last_6mths": {
#         "0": 0.0
#     },
#     "mths_since_last_delinq": {
#         "0": null
#     },
#     "mths_since_last_record": {
#         "0": null
#     },
#     "open_acc": {
#         "0": 5.0
#     },
#     "pub_rec": {
#         "0": 0.0
#     },
#     "revol_bal": {
#         "0": 11638.0
#     },
#     "revol_util": {
#         "0": 36.4
#     },
#     "total_acc": {
#         "0": 7.0
#     },
#     "initial_list_status": {
#         "0": "f"
#     },
#     "out_prncp": {
#         "0": 0.0
#     },
#     "out_prncp_inv": {
#         "0": 0.0
#     },
#     "total_pymnt": {
#         "0": 12157.3800468
#     },
#     "total_pymnt_inv": {
#         "0": 12157.38
#     },
#     "total_rec_prncp": {
#         "0": 11000.0
#     },
#     "total_rec_int": {
#         "0": 1157.38
#     },
#     "total_rec_late_fee": {
#         "0": 0.0
#     },
#     "recoveries": {
#         "0": 0.0
#     },
#     "collection_recovery_fee": {
#         "0": 0.0
#     },
#     "last_pymnt_d": {
#         "0": "Jan-2015"
#     },
#     "last_pymnt_amnt": {
#         "0": 346.13
#     },
#     "next_pymnt_d": {
#         "0": null
#     },
#     "last_credit_pull_d": {
#         "0": "Jan-2016"
#     },
#     "collections_12_mths_ex_med": {
#         "0": 0.0
#     },
#     "mths_since_last_major_derog": {
#         "0": null
#     },
#     "policy_code": {
#         "0": 1.0
#     },
#     "application_type": {
#         "0": "INDIVIDUAL"
#     },
#     "annual_inc_joint": {
#         "0": null
#     },
#     "dti_joint": {
#         "0": null
#     },
#     "verification_status_joint": {
#         "0": null
#     },
#     "acc_now_delinq": {
#         "0": 0.0
#     },
#     "tot_coll_amt": {
#         "0": null
#     },
#     "tot_cur_bal": {
#         "0": null
#     },
#     "open_acc_6m": {
#         "0": null
#     },
#     "open_il_6m": {
#         "0": null
#     },
#     "open_il_12m": {
#         "0": null
#     },
#     "open_il_24m": {
#         "0": null
#     },
#     "mths_since_rcnt_il": {
#         "0": null
#     },
#     "total_bal_il": {
#         "0": null
#     },
#     "il_util": {
#         "0": null
#     },
#     "open_rv_12m": {
#         "0": null
#     },
#     "open_rv_24m": {
#         "0": null
#     },
#     "max_bal_bc": {
#         "0": null
#     },
#     "all_util": {
#         "0": null
#     },
#     "total_rev_hi_lim": {
#         "0": null
#     },
#     "inq_fi": {
#         "0": null
#     },
#     "total_cu_tl": {
#         "0": null
#     },
#     "inq_last_12m": {
#         "0": null
#     }
# }
